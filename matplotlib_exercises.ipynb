# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Use matplotlib to plot the following equation:
# y = x^2 - x + 2
# You'll need to write the code that generates the x and y points.
# Add an anotation for the point 0, 0, the origin.

x = range(0, 10)
y = [(n ** 2 - n + 2) for n in x]
fig = plt.figure(figsize = (10, 10)) 

#Add title
plt.title('$y = x^2 - x +2$')
#Add labels
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.plot(x, y)

plt.annotate('This is the origin (0,0)', xy = (0, 0), xytext = (1, 20), 
             arrowprops = {'facecolor': 'green'})
plt.show()

# %%
#Create and label 4 separate charts for the following equations 
#(choose a range for x that makes sense):
# y=√x y=x^3 y=2^x y=1/(x+1) 
#You can use functions from the math module to help implement some of the 
#equations above.
from math import sqrt
x = range(0,100)
y = [math.sqrt(n) for n in x]

fig = plt.figure(figsize = (10,3))

plt.plot(x, y)

plt.title('$y = √x $')
#Add labels
plt.xlabel('x')
plt.ylabel('$ √x $')

plt.grid(True, ls = '--')

# %%
x = range(0,100)
y = [(n ** 3) for n in x]

fig = plt.figure(figsize = (10,3))

plt.plot(x, y)

plt.title('$y = x^3$')
#Add labels
plt.xlabel('x')
plt.ylabel('$x^3$')

plt.grid(True, ls = '--')

# %%
x = range(0,100)
y = [(2 ** n) for n in x]

fig = plt.figure(figsize = (10,3))

plt.plot(x, y)

plt.title('$y = 2^x$')
#Add labels
plt.xlabel('x')
plt.ylabel('$2^x$')
plt.grid(True, ls = '--')

# %%
x = range(0,30)
y = [(1/(n+1)) for n in x]

fig = plt.figure(figsize = (10,3))

plt.plot(x, y)

plt.title('$y=1/(x+1)$')
#Add labels
plt.xlabel('x')
plt.ylabel('$1/(x+1)$')
plt.grid(True, ls = '--')

# %%
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

fig = plt.figure(figsize = (8,5))
plt.suptitle('4 subplots')

# subplot #1
plt.subplot(221)
x = range(0,100)
y = [math.sqrt(n) for n in x]

plt.plot(x, y)

plt.title('$y = √x $')
#Add labels
plt.xlabel('x')
plt.ylabel('$ √x $')

plt.grid(True, ls = '--')


# subplot #2
plt.subplot(222)
x = range(0,100)
y = [(n ** 3) for n in x]

plt.plot(x, y)

plt.title('$y = x^3$')
#Add labels
plt.xlabel('x')
plt.ylabel('$x^3$')
plt.grid(True, ls = '--')


# subplot #3
plt.subplot(223)
x = range(0,15)
y = [(2 ** n) for n in x]

plt.plot(x, y)
plt.title('$y = 2^x$')
#Add labels
plt.xlabel('x')
plt.ylabel('$2^x$')
plt.grid(True, ls = '--')


# subplot #4
plt.subplot(224)
x = range(0,30)
y = [(1/(n+1)) for n in x]

plt.plot(x, y)

plt.title('$y=1/(x+1)$')
#Add labels
plt.xlabel('x')
plt.ylabel('$1/(x+1)$')
plt.grid(True, ls = '--')

# to make plots not overlap
plt.tight_layout()

# %%
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# define a figure

fig = plt.figure(figsize = (10,6))

x = list(range(0,25))

# define multiple y's
y1 = [math.sqrt(n) for n in x]
y2 = [(n ** 3) for n in x]
y3 = [(2 ** n) for n in x]
y4 = [(1/(n+1)) for n in x]

plt.plot(x, y1, c = '#444444', label = '$\sqrt{x}$', linestyle = '--', alpha=1.0)
plt.plot(x, y2, c = 'r', label='$x^{3}$', alpha=1.0)
plt.plot(x, y3, c = 'green', label='$2^{x}$', alpha=.7)
plt.plot(x, y4, c = 'c', label='$1/(x+1)$', alpha=0.8)

plt.ylim(0, 8)
plt.xlim(0, 8)

plt.title('Functions')
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.grid(True, ls = '--')
plt.legend()
plt.show()
